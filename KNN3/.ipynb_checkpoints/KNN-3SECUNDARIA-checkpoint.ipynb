# %% [markdown]
# ## 3 Año de secundaria

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.patches as mpatches
import seaborn as sb
from sklearn import datasets, neighbors
from mlxtend.plotting import plot_decision_regions

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Nota: Considerar que los datos deben tener formato UTF-8, es decir los caracteres propios del idioma español deberían ser transdormados a símbolos

# %% [markdown]
# Los datos se perciben del archivo denominado "data_3sec.csv", pandas trabaja muy bien con esos datos. Posteriormente se procede a extraer los 5 primeros datos, esto para asegurarnos que no hayan problemas de formato de letra y que pandas con la librería read_csv, correctamente importen los datos. Esto es posible con el método head(), este permitirá traer los 5 primeros registros

# %%
dataframe = pd.read_csv(r"data_3secundaria.csv",sep=';')
dataframe.head()
# Out:
#     id seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_alg_2019  pf_alg_2020  \
# 0  488       A    16      15      16      20           15           16
# 1  489       A    17      12      15      20           14           14
# 2  490       A    16      12      13      18           15           16
# 3  491       A    16      18      17      18           14           15
# 4  492       A    16      15      14      19           16           15
#
#    alg_1b_2021  alg_2b_2021  ...  condicion_pago                  pe1  \
# 0           16           15  ...           deuda                Facil
# 1           14           13  ...           deuda                Facil
# 2           16           13  ...           deuda  Ni Facil ni Dificil
# 3           17           14  ...           deuda                Facil
# 4           17           15  ...           deuda                Facil
#
#                    pe2    pe3                  pe4    pe5  horas_asincronas  \
# 0  Ni Facil ni Dificil  Facil                Facil  Bueno           3 horas
# 1  Ni Facil ni Dificil  Facil                Facil  Bueno           3 horas
# 2  Ni Facil ni Dificil  Facil  Ni Facil ni Dificil  Bueno           3 horas
# 3  Ni Facil ni Dificil  Facil                Facil  Bueno           3 horas
# 4  Ni Facil ni Dificil  Facil                Facil  Bueno           3 horas
#
#    valoracion_clases  dispos_clases  calidad_internet
# 0         Satisfecho              4             Buena
# 1         Satisfecho              1             Buena
# 2         Satisfecho              1             Buena
# 3         Satisfecho              1             Buena
# 4         Satisfecho              1             Buena
#
# [5 rows x 40 columns]

# %% [markdown]
# Podríamos realizar la llamada a n registros con la misma función pero cambiando el parámetro

# %%
dataframe.head(10)
# Out:
#     id seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_alg_2019  pf_alg_2020  \
# 0  488       A    16      15      16      20           15           16
# 1  489       A    17      12      15      20           14           14
# 2  490       A    16      12      13      18           15           16
# 3  491       A    16      18      17      18           14           15
# 4  492       A    16      15      14      19           16           15
# 5  493       A    16       9      10      17           12           11
# 6  494       A    17       9      11      15           11           11
# 7  495       A    17      14      14      19           17           16
# 8  496       A    17       9      10      17           11           11
# 9  497       A    17      14      15      20           15           13
#
#    alg_1b_2021  alg_2b_2021  ...  condicion_pago                  pe1  \
# 0           16           15  ...           deuda                Facil
# 1           14           13  ...           deuda                Facil
# 2           16           13  ...           deuda  Ni Facil ni Dificil
# 3           17           14  ...           deuda                Facil
# 4           17           15  ...           deuda                Facil
# 5           10           11  ...           deuda  Ni Facil ni Dificil
# 6            9           10  ...           deuda  Ni Facil ni Dificil
# 7           14           14  ...           deuda                Facil
# 8            9           11  ...           deuda  Ni Facil ni Dificil
# 9           16           15  ...           deuda                Facil
#
#                    pe2                  pe3                  pe4          pe5  \
# 0  Ni Facil ni Dificil                Facil                Facil        Bueno
# 1  Ni Facil ni Dificil                Facil                Facil        Bueno
# 2  Ni Facil ni Dificil                Facil  Ni Facil ni Dificil        Bueno
# 3  Ni Facil ni Dificil                Facil                Facil        Bueno
# 4  Ni Facil ni Dificil                Facil                Facil        Bueno
# 5              Dificil  Ni Facil ni Dificil  Ni Facil ni Dificil  Indiferente
# 6              Dificil  Ni Facil ni Dificil  Ni Facil ni Dificil  Indiferente
# 7  Ni Facil ni Dificil                Facil                Facil        Bueno
# 8              Dificil  Ni Facil ni Dificil  Ni Facil ni Dificil  Indiferente
# 9                Facil                Facil                Facil        Bueno
#
#    horas_asincronas  valoracion_clases  dispos_clases  calidad_internet
# 0           3 horas         Satisfecho              4             Buena
# 1           3 horas         Satisfecho              1             Buena
# 2           3 horas         Satisfecho              1             Buena
# 3           3 horas         Satisfecho              1             Buena
# 4           3 horas         Satisfecho              1             Buena
# 5           2 horas        Indiferente              2             Media
# 6           2 horas        Indiferente              3             Media
# 7           3 horas         Satisfecho              4             Buena
# 8           2 horas        Indiferente              1             Media
# 9           3 horas         Satisfecho              1             Buena
#
# [10 rows x 40 columns]

# %% [markdown]
# Visualizamos estadísticamente a los datos con el método describe()

# %%
dataframe.describe()
# Out:
#                id        edad      pf_ac1      pf_ac2      pf_ac3  \
# count  224.000000  224.000000  224.000000  224.000000  224.000000
# mean   599.500000   16.477679   14.138393   15.187500   17.919643
# std     64.807407    0.500620    2.611384    2.206924    1.819862
# min    488.000000   16.000000    7.000000    8.000000   10.000000
# 25%    543.750000   16.000000   12.000000   14.000000   17.000000
# 50%    599.500000   16.000000   14.000000   15.000000   18.000000
# 75%    655.250000   17.000000   16.000000   17.000000   19.000000
# max    711.000000   17.000000   20.000000   20.000000   20.000000
#
#        pf_alg_2019  pf_alg_2020  alg_1b_2021  alg_2b_2021  alg_3b_2021  ...  \
# count   224.000000   224.000000   224.000000   224.000000   224.000000  ...
# mean     15.044643    15.098214    14.415179    14.955357    15.879464  ...
# std       2.519479     2.478463     2.327828     2.556583     2.878516  ...
# min      11.000000    11.000000     7.000000     8.000000     8.000000  ...
# 25%      13.000000    13.000000    13.000000    13.000000    14.000000  ...
# 50%      15.000000    15.000000    15.000000    15.000000    16.000000  ...
# 75%      17.000000    17.000000    16.000000    17.000000    18.000000  ...
# max      20.000000    20.000000    19.000000    19.000000    20.000000  ...
#
#        pf_geo_2019  pf_geo_2020  geo_1b_2021  geo_2b_2021  geo_3b_2021  \
# count   224.000000   224.000000   224.000000   224.000000   224.000000
# mean     14.941964    15.107143    14.022321    15.040179    15.196429
# std       2.425801     2.623991     2.459436     2.828933     3.131897
# min      11.000000    11.000000     9.000000     8.000000     8.000000
# 25%      13.000000    13.000000    12.000000    13.000000    13.000000
# 50%      15.000000    15.000000    14.000000    15.000000    16.000000
# 75%      17.000000    17.000000    16.000000    18.000000    18.000000
# max      20.000000    20.000000    20.000000    19.000000    20.000000
#
#        geo_4b_2021  ind_nivel_geo  grupo_mate  anios_colegio  dispos_clases
# count   224.000000     224.000000       224.0          224.0     224.000000
# mean     15.111607       2.651786         0.0            5.0       2.468750
# std       2.895961       0.477471         0.0            0.0       1.212382
# min       4.000000       2.000000         0.0            5.0       1.000000
# 25%      13.000000       2.000000         0.0            5.0       1.000000
# 50%      15.000000       3.000000         0.0            5.0       2.000000
# 75%      17.000000       3.000000         0.0            5.0       3.000000
# max      20.000000       3.000000         0.0            5.0       5.000000
#
# [8 rows x 29 columns]

# %% [markdown]
# Este resultado nos da muchos indicadores, entre los cuales destacan el aseguramiento de tener la cantidad correcta de cada campo del dataframe, así como los valores de media, desviación estándar y los mínimos y máximos.
#
# Sin embargo el detalle más resaltantes es que no se han considerado todas las columnas en las que se ven letras, por tanto se necesita mapear los avlores literales a números, tal es el caso del campo: "condicion_pago". En primer lugar se hará la conversión de los datos de dicha columna y se procederá a hacer lo mismo con el resto de valores no numéricos

# %%
dataframe["condicion_pago"]
# Out:
# 0      deuda
# 1      deuda
# 2      deuda
# 3      deuda
# 4      deuda
#        ...
# 219    deuda
# 220    deuda
# 221    deuda
# 222    deuda
# 223    deuda
# Name: condicion_pago, Length: 224, dtype: object

# %% [markdown]
# Entonces convertimos datos categóricos, ordinales  a numéricos

# %%
values_condicion_pago = dataframe["condicion_pago"].astype("category").cat.codes
dataframe["condicion_pago"] = values_condicion_pago

# %% [markdown]
# Los nuevos valores son ya numéricos

# %%
dataframe["condicion_pago"]
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 219    0
# 220    0
# 221    0
# 222    0
# 223    0
# Name: condicion_pago, Length: 224, dtype: int8

# %%
dataframe.head(10)
# Out:
#     id seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_alg_2019  pf_alg_2020  \
# 0  488       A    16      15      16      20           15           16
# 1  489       A    17      12      15      20           14           14
# 2  490       A    16      12      13      18           15           16
# 3  491       A    16      18      17      18           14           15
# 4  492       A    16      15      14      19           16           15
# 5  493       A    16       9      10      17           12           11
# 6  494       A    17       9      11      15           11           11
# 7  495       A    17      14      14      19           17           16
# 8  496       A    17       9      10      17           11           11
# 9  497       A    17      14      15      20           15           13
#
#    alg_1b_2021  alg_2b_2021  ...  condicion_pago                  pe1  \
# 0           16           15  ...               0                Facil
# 1           14           13  ...               0                Facil
# 2           16           13  ...               0  Ni Facil ni Dificil
# 3           17           14  ...               0                Facil
# 4           17           15  ...               0                Facil
# 5           10           11  ...               0  Ni Facil ni Dificil
# 6            9           10  ...               0  Ni Facil ni Dificil
# 7           14           14  ...               0                Facil
# 8            9           11  ...               0  Ni Facil ni Dificil
# 9           16           15  ...               0                Facil
#
#                    pe2                  pe3                  pe4          pe5  \
# 0  Ni Facil ni Dificil                Facil                Facil        Bueno
# 1  Ni Facil ni Dificil                Facil                Facil        Bueno
# 2  Ni Facil ni Dificil                Facil  Ni Facil ni Dificil        Bueno
# 3  Ni Facil ni Dificil                Facil                Facil        Bueno
# 4  Ni Facil ni Dificil                Facil                Facil        Bueno
# 5              Dificil  Ni Facil ni Dificil  Ni Facil ni Dificil  Indiferente
# 6              Dificil  Ni Facil ni Dificil  Ni Facil ni Dificil  Indiferente
# 7  Ni Facil ni Dificil                Facil                Facil        Bueno
# 8              Dificil  Ni Facil ni Dificil  Ni Facil ni Dificil  Indiferente
# 9                Facil                Facil                Facil        Bueno
#
#    horas_asincronas  valoracion_clases  dispos_clases  calidad_internet
# 0           3 horas         Satisfecho              4             Buena
# 1           3 horas         Satisfecho              1             Buena
# 2           3 horas         Satisfecho              1             Buena
# 3           3 horas         Satisfecho              1             Buena
# 4           3 horas         Satisfecho              1             Buena
# 5           2 horas        Indiferente              2             Media
# 6           2 horas        Indiferente              3             Media
# 7           3 horas         Satisfecho              4             Buena
# 8           2 horas        Indiferente              1             Media
# 9           3 horas         Satisfecho              1             Buena
#
# [10 rows x 40 columns]

# %%
values_pe1 = dataframe["pe1"].astype("category").cat.codes
dataframe["pe1"] = values_pe1

dataframe.head(10)
# Out:
#     id seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_alg_2019  pf_alg_2020  \
# 0  488       A    16      15      16      20           15           16
# 1  489       A    17      12      15      20           14           14
# 2  490       A    16      12      13      18           15           16
# 3  491       A    16      18      17      18           14           15
# 4  492       A    16      15      14      19           16           15
# 5  493       A    16       9      10      17           12           11
# 6  494       A    17       9      11      15           11           11
# 7  495       A    17      14      14      19           17           16
# 8  496       A    17       9      10      17           11           11
# 9  497       A    17      14      15      20           15           13
#
#    alg_1b_2021  alg_2b_2021  ...  condicion_pago  pe1                  pe2  \
# 0           16           15  ...               0    0  Ni Facil ni Dificil
# 1           14           13  ...               0    0  Ni Facil ni Dificil
# 2           16           13  ...               0    3  Ni Facil ni Dificil
# 3           17           14  ...               0    0  Ni Facil ni Dificil
# 4           17           15  ...               0    0  Ni Facil ni Dificil
# 5           10           11  ...               0    3              Dificil
# 6            9           10  ...               0    3              Dificil
# 7           14           14  ...               0    0  Ni Facil ni Dificil
# 8            9           11  ...               0    3              Dificil
# 9           16           15  ...               0    0                Facil
#
#                    pe3                  pe4          pe5  horas_asincronas  \
# 0                Facil                Facil        Bueno           3 horas
# 1                Facil                Facil        Bueno           3 horas
# 2                Facil  Ni Facil ni Dificil        Bueno           3 horas
# 3                Facil                Facil        Bueno           3 horas
# 4                Facil                Facil        Bueno           3 horas
# 5  Ni Facil ni Dificil  Ni Facil ni Dificil  Indiferente           2 horas
# 6  Ni Facil ni Dificil  Ni Facil ni Dificil  Indiferente           2 horas
# 7                Facil                Facil        Bueno           3 horas
# 8  Ni Facil ni Dificil  Ni Facil ni Dificil  Indiferente           2 horas
# 9                Facil                Facil        Bueno           3 horas
#
#    valoracion_clases  dispos_clases  calidad_internet
# 0         Satisfecho              4             Buena
# 1         Satisfecho              1             Buena
# 2         Satisfecho              1             Buena
# 3         Satisfecho              1             Buena
# 4         Satisfecho              1             Buena
# 5        Indiferente              2             Media
# 6        Indiferente              3             Media
# 7         Satisfecho              4             Buena
# 8        Indiferente              1             Media
# 9         Satisfecho              1             Buena
#
# [10 rows x 40 columns]

# %%
values_pe2 = dataframe["pe2"].astype("category").cat.codes
dataframe["pe2"] = values_pe2

values_pe3 = dataframe["pe3"].astype("category").cat.codes
dataframe["pe3"] = values_pe3

values_pe4 = dataframe["pe4"].astype("category").cat.codes
dataframe["pe4"] = values_pe4

values_pe5 = dataframe["pe5"].astype("category").cat.codes
dataframe["pe5"] = values_pe5



dataframe.head(10)
# Out:
#     id seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_alg_2019  pf_alg_2020  \
# 0  488       A    16      15      16      20           15           16
# 1  489       A    17      12      15      20           14           14
# 2  490       A    16      12      13      18           15           16
# 3  491       A    16      18      17      18           14           15
# 4  492       A    16      15      14      19           16           15
# 5  493       A    16       9      10      17           12           11
# 6  494       A    17       9      11      15           11           11
# 7  495       A    17      14      14      19           17           16
# 8  496       A    17       9      10      17           11           11
# 9  497       A    17      14      15      20           15           13
#
#    alg_1b_2021  alg_2b_2021  ...  condicion_pago  pe1  pe2  pe3  pe4  pe5  \
# 0           16           15  ...               0    0    3    0    0    0
# 1           14           13  ...               0    0    3    0    0    0
# 2           16           13  ...               0    3    3    0    3    0
# 3           17           14  ...               0    0    3    0    0    0
# 4           17           15  ...               0    0    3    0    0    0
# 5           10           11  ...               0    3    0    2    3    2
# 6            9           10  ...               0    3    0    2    3    2
# 7           14           14  ...               0    0    3    0    0    0
# 8            9           11  ...               0    3    0    2    3    2
# 9           16           15  ...               0    0    1    0    0    0
#
#    horas_asincronas  valoracion_clases  dispos_clases  calidad_internet
# 0           3 horas         Satisfecho              4             Buena
# 1           3 horas         Satisfecho              1             Buena
# 2           3 horas         Satisfecho              1             Buena
# 3           3 horas         Satisfecho              1             Buena
# 4           3 horas         Satisfecho              1             Buena
# 5           2 horas        Indiferente              2             Media
# 6           2 horas        Indiferente              3             Media
# 7           3 horas         Satisfecho              4             Buena
# 8           2 horas        Indiferente              1             Media
# 9           3 horas         Satisfecho              1             Buena
#
# [10 rows x 40 columns]

# %%
values_seccion = dataframe["seccion"].astype("category").cat.codes
dataframe["seccion"] = values_seccion

dataframe.head(10)
# Out:
#     id  seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_alg_2019  pf_alg_2020  \
# 0  488        0    16      15      16      20           15           16
# 1  489        0    17      12      15      20           14           14
# 2  490        0    16      12      13      18           15           16
# 3  491        0    16      18      17      18           14           15
# 4  492        0    16      15      14      19           16           15
# 5  493        0    16       9      10      17           12           11
# 6  494        0    17       9      11      15           11           11
# 7  495        0    17      14      14      19           17           16
# 8  496        0    17       9      10      17           11           11
# 9  497        0    17      14      15      20           15           13
#
#    alg_1b_2021  alg_2b_2021  ...  condicion_pago  pe1  pe2  pe3  pe4  pe5  \
# 0           16           15  ...               0    0    3    0    0    0
# 1           14           13  ...               0    0    3    0    0    0
# 2           16           13  ...               0    3    3    0    3    0
# 3           17           14  ...               0    0    3    0    0    0
# 4           17           15  ...               0    0    3    0    0    0
# 5           10           11  ...               0    3    0    2    3    2
# 6            9           10  ...               0    3    0    2    3    2
# 7           14           14  ...               0    0    3    0    0    0
# 8            9           11  ...               0    3    0    2    3    2
# 9           16           15  ...               0    0    1    0    0    0
#
#    horas_asincronas  valoracion_clases  dispos_clases  calidad_internet
# 0           3 horas         Satisfecho              4             Buena
# 1           3 horas         Satisfecho              1             Buena
# 2           3 horas         Satisfecho              1             Buena
# 3           3 horas         Satisfecho              1             Buena
# 4           3 horas         Satisfecho              1             Buena
# 5           2 horas        Indiferente              2             Media
# 6           2 horas        Indiferente              3             Media
# 7           3 horas         Satisfecho              4             Buena
# 8           2 horas        Indiferente              1             Media
# 9           3 horas         Satisfecho              1             Buena
#
# [10 rows x 40 columns]

# %%
values_horas_asincronas = dataframe["horas_asincronas"].astype("category").cat.codes
dataframe["horas_asincronas"] = values_horas_asincronas

values_valoracion_clases = dataframe["valoracion_clases"].astype("category").cat.codes
dataframe["valoracion_clases"] = values_valoracion_clases

values_calidad_internet = dataframe["calidad_internet"].astype("category").cat.codes
dataframe["calidad_internet"] = values_calidad_internet

dataframe.head(10)
# Out:
#     id  seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_alg_2019  pf_alg_2020  \
# 0  488        0    16      15      16      20           15           16
# 1  489        0    17      12      15      20           14           14
# 2  490        0    16      12      13      18           15           16
# 3  491        0    16      18      17      18           14           15
# 4  492        0    16      15      14      19           16           15
# 5  493        0    16       9      10      17           12           11
# 6  494        0    17       9      11      15           11           11
# 7  495        0    17      14      14      19           17           16
# 8  496        0    17       9      10      17           11           11
# 9  497        0    17      14      15      20           15           13
#
#    alg_1b_2021  alg_2b_2021  ...  condicion_pago  pe1  pe2  pe3  pe4  pe5  \
# 0           16           15  ...               0    0    3    0    0    0
# 1           14           13  ...               0    0    3    0    0    0
# 2           16           13  ...               0    3    3    0    3    0
# 3           17           14  ...               0    0    3    0    0    0
# 4           17           15  ...               0    0    3    0    0    0
# 5           10           11  ...               0    3    0    2    3    2
# 6            9           10  ...               0    3    0    2    3    2
# 7           14           14  ...               0    0    3    0    0    0
# 8            9           11  ...               0    3    0    2    3    2
# 9           16           15  ...               0    0    1    0    0    0
#
#    horas_asincronas  valoracion_clases  dispos_clases  calidad_internet
# 0                 1                  2              4                 0
# 1                 1                  2              1                 0
# 2                 1                  2              1                 0
# 3                 1                  2              1                 0
# 4                 1                  2              1                 0
# 5                 0                  0              2                 1
# 6                 0                  0              3                 1
# 7                 1                  2              4                 0
# 8                 0                  0              1                 1
# 9                 1                  2              1                 0
#
# [10 rows x 40 columns]

# %%
values_genero = dataframe["genero"].astype("category").cat.codes
dataframe["genero"] = values_genero

dataframe.head(10)
# Out:
#     id  seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_alg_2019  pf_alg_2020  \
# 0  488        0    16      15      16      20           15           16
# 1  489        0    17      12      15      20           14           14
# 2  490        0    16      12      13      18           15           16
# 3  491        0    16      18      17      18           14           15
# 4  492        0    16      15      14      19           16           15
# 5  493        0    16       9      10      17           12           11
# 6  494        0    17       9      11      15           11           11
# 7  495        0    17      14      14      19           17           16
# 8  496        0    17       9      10      17           11           11
# 9  497        0    17      14      15      20           15           13
#
#    alg_1b_2021  alg_2b_2021  ...  condicion_pago  pe1  pe2  pe3  pe4  pe5  \
# 0           16           15  ...               0    0    3    0    0    0
# 1           14           13  ...               0    0    3    0    0    0
# 2           16           13  ...               0    3    3    0    3    0
# 3           17           14  ...               0    0    3    0    0    0
# 4           17           15  ...               0    0    3    0    0    0
# 5           10           11  ...               0    3    0    2    3    2
# 6            9           10  ...               0    3    0    2    3    2
# 7           14           14  ...               0    0    3    0    0    0
# 8            9           11  ...               0    3    0    2    3    2
# 9           16           15  ...               0    0    1    0    0    0
#
#    horas_asincronas  valoracion_clases  dispos_clases  calidad_internet
# 0                 1                  2              4                 0
# 1                 1                  2              1                 0
# 2                 1                  2              1                 0
# 3                 1                  2              1                 0
# 4                 1                  2              1                 0
# 5                 0                  0              2                 1
# 6                 0                  0              3                 1
# 7                 1                  2              4                 0
# 8                 0                  0              1                 1
# 9                 1                  2              1                 0
#
# [10 rows x 40 columns]

# %% [markdown]
# Vamos a darle un poco de visualización

# %%
dataframe.hist(['edad','pf_ac1','pf_ac2','pf_ac3','pf_alg_2019','pf_alg_2020','alg_1b_2021','alg_2b_2021',
               'alg_3b_2021','alg_4b_2021','grupo_mate','genero'])
plt.show()

# %%
dataframe['ind_nivel_algebra']
# Out:
# 0      3
# 1      2
# 2      3
# 3      3
# 4      3
#       ..
# 219    3
# 220    3
# 221    3
# 222    3
# 223    3
# Name: ind_nivel_algebra, Length: 224, dtype: int64

# %%
dataframe.hist(['edad','pf_ac1','pf_ac2','pf_ac3','pf_apm_2019','pf_apm_2020','am_1b_2021','am_2b_2021',
               'am_3b_2021','am_4b_2021','grupo_mate','genero'])

plt.show()

# %%
dataframe['ind_nivel_am']
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
#       ..
# 219    2
# 220    2
# 221    2
# 222    1
# 223    2
# Name: ind_nivel_am, Length: 224, dtype: int64

# %%
dataframe.hist(['edad','pf_ac1','pf_ac2','pf_ac3','pf_geo_2019','pf_geo_2020','geo_1b_2021','geo_2b_2021',
               'geo_3b_2021','geo_4b_2021','grupo_mate','genero'])
y = dataframe['ind_nivel_geo'].values
plt.show()

# %%
dataframe['ind_nivel_geo']
# Out:
# 0      3
# 1      3
# 2      2
# 3      3
# 4      2
#       ..
# 219    3
# 220    3
# 221    3
# 222    2
# 223    3
# Name: ind_nivel_geo, Length: 224, dtype: int64

# %% [markdown]
# ## Preparación de las entradas

# %% [markdown]
# <p style="color:red;font-size:2rem"> <b>Para el caso de Álgebra </b></p>

# %%
X = dataframe[['id','seccion','edad','pf_ac1','pf_ac2','pf_ac3','pf_alg_2019','pf_alg_2020','alg_1b_2021','alg_2b_2021',
               'alg_3b_2021','alg_4b_2021','grupo_mate','genero',
               'anios_colegio','condicion_pago','pe3','pe5','horas_asincronas','valoracion_clases',
               'dispos_clases','calidad_internet']].values
y = dataframe['ind_nivel_algebra'].values
 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
n_neighbors = 8
knn = KNeighborsClassifier(n_neighbors)
knn.fit(X_train, y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.91
# Accuracy of K-NN classifier on test set: 0.88

# %% [markdown]
# #### Precisión del modelo

# %%
pred = knn.predict(X_test)
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[18  6]
#  [ 1 31]]
#               precision    recall  f1-score   support
#
#            2       0.95      0.75      0.84        24
#            3       0.84      0.97      0.90        32
#
#     accuracy                           0.88        56
#    macro avg       0.89      0.86      0.87        56
# weighted avg       0.88      0.88      0.87        56

# %%
correlation_matrix = dataframe[['id','seccion','edad','pf_ac1','pf_ac2','pf_ac3','pf_alg_2019','pf_alg_2020','alg_1b_2021','alg_2b_2021',
               'alg_3b_2021','alg_4b_2021','grupo_mate','genero',
               'anios_colegio','condicion_pago','pe3','pe5','horas_asincronas','valoracion_clases',
               'dispos_clases','calidad_internet','ind_nivel_algebra']].corr()
correlation_matrix["ind_nivel_algebra"]
# Out:
# id                   0.201208
# seccion              0.198309
# edad                -0.023632
# pf_ac1               0.648815
# pf_ac2               0.597486
# pf_ac3               0.425292
# pf_alg_2019          0.767608
# pf_alg_2020          0.720737
# alg_1b_2021          0.743401
# alg_2b_2021          0.719644
# alg_3b_2021          0.769300
# alg_4b_2021          0.605100
# grupo_mate                NaN
# genero              -0.013094
# anios_colegio             NaN
# condicion_pago            NaN
# pe3                 -0.097469
# pe5                 -0.501105
# horas_asincronas     0.639839
# valoracion_clases    0.501105
# dispos_clases       -0.046102
# calidad_internet    -0.021308
# ind_nivel_algebra    1.000000
# Name: ind_nivel_algebra, dtype: float64

# %%
def knn_comparison(data, k):
    x = data[['horas_asincronas','valoracion_clases']].values
    y = data['ind_nivel_am'].values

    clf = neighbors.KNeighborsClassifier(n_neighbors=k)

    clf.fit(x, y)
    # Plotting decision region
    plot_decision_regions(x, y, clf=clf, legend=2)
    # Adding axes annotations
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Knn with K=8')
    plt.show()
    

knn_comparison(dataframe, 8)

# %% [markdown]
# <p style="color:red;font-size:2rem"> <b>Para el caso de Aptitud matemática </b></p>

# %%
X = dataframe[['id','seccion','edad','pf_ac1','pf_ac2','pf_ac3','pf_apm_2019','pf_apm_2020','am_1b_2021','am_2b_2021',
               'am_3b_2021','am_4b_2021','grupo_mate','genero',
               'anios_colegio','condicion_pago','pe2','pe4','pe5','horas_asincronas','valoracion_clases',
               'dispos_clases','calidad_internet']].values
y = dataframe['ind_nivel_am'].values
 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
n_neighbors = 8
knn = KNeighborsClassifier(n_neighbors)
knn.fit(X_train, y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 0.89
# Accuracy of K-NN classifier on test set: 0.93

# %%
df = dataframe[['id','seccion','edad','pf_ac1','pf_ac2','pf_ac3','pf_apm_2019','pf_apm_2020','am_1b_2021','am_2b_2021',
               'am_3b_2021','am_4b_2021','grupo_mate','genero',
               'anios_colegio','condicion_pago','pe2','pe4','pe5','horas_asincronas','valoracion_clases',
               'dispos_clases','calidad_internet']]

df
# Out:
#       id  seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_apm_2019  pf_apm_2020  \
# 0    488        0    16      15      16      20           11           11
# 1    489        0    17      12      15      20           12           11
# 2    490        0    16      12      13      18           15           11
# 3    491        0    16      18      17      18           11           13
# 4    492        0    16      15      14      19           11           12
# ..   ...      ...   ...     ...     ...     ...          ...          ...
# 219  707        7    17      16      14      18           11           11
# 220  708        7    16      15      16      18           11           13
# 221  709        7    16      16      16      19           14           11
# 222  710        7    17      16      14      15           11           11
# 223  711        7    17      15      17      20           11           14
#
#      am_1b_2021  am_2b_2021  ...  genero  anios_colegio  condicion_pago  pe2  \
# 0            12          13  ...       0              5               0    3
# 1            12          11  ...       0              5               0    3
# 2            15          10  ...       1              5               0    3
# 3            14          14  ...       0              5               0    3
# 4            12          13  ...       0              5               0    3
# ..          ...         ...  ...     ...            ...             ...  ...
# 219          11          13  ...       1              5               0    3
# 220          12          10  ...       1              5               0    3
# 221          11          14  ...       1              5               0    3
# 222           9           7  ...       1              5               0    0
# 223          16          13  ...       0              5               0    1
#
#      pe4  pe5  horas_asincronas  valoracion_clases  dispos_clases  \
# 0      0    0                 1                  2              4
# 1      0    0                 1                  2              1
# 2      3    0                 1                  2              1
# 3      0    0                 1                  2              1
# 4      0    0                 1                  2              1
# ..   ...  ...               ...                ...            ...
# 219    0    0                 1                  2              4
# 220    0    0                 1                  2              2
# 221    0    0                 1                  2              3
# 222    0    0                 1                  2              1
# 223    2    0                 1                  2              3
#
#      calidad_internet
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0
# ..                ...
# 219                 0
# 220                 0
# 221                 0
# 222                 0
# 223                 0
#
# [224 rows x 23 columns]

# %% [markdown]
# #### Precisión del modelo

# %%
pred = knn.predict(X_test)
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[ 8  1  0]
#  [ 0 44  1]
#  [ 0  2  0]]
#               precision    recall  f1-score   support
#
#            1       1.00      0.89      0.94         9
#            2       0.94      0.98      0.96        45
#            3       0.00      0.00      0.00         2
#
#     accuracy                           0.93        56
#    macro avg       0.65      0.62      0.63        56
# weighted avg       0.91      0.93      0.92        56

# %%
correlation_matrix = dataframe[['id','seccion','edad','pf_ac1','pf_ac2','pf_ac3','pf_apm_2019','pf_apm_2020','am_1b_2021','am_2b_2021',
               'am_3b_2021','am_4b_2021','grupo_mate','genero',
               'anios_colegio','condicion_pago','pe2','pe4','pe5','horas_asincronas','valoracion_clases',
               'dispos_clases','calidad_internet','ind_nivel_am']].corr()
correlation_matrix["ind_nivel_am"]
# Out:
# id                  -0.075750
# seccion             -0.088490
# edad                -0.054323
# pf_ac1               0.635011
# pf_ac2               0.562780
# pf_ac3               0.430020
# pf_apm_2019          0.421107
# pf_apm_2020          0.519191
# am_1b_2021           0.645745
# am_2b_2021           0.711360
# am_3b_2021           0.726339
# am_4b_2021           0.580571
# grupo_mate                NaN
# genero              -0.056983
# anios_colegio             NaN
# condicion_pago            NaN
# pe2                  0.274093
# pe4                 -0.065619
# pe5                 -0.271954
# horas_asincronas     0.595662
# valoracion_clases    0.271954
# dispos_clases        0.053043
# calidad_internet     0.183198
# ind_nivel_am         1.000000
# Name: ind_nivel_am, dtype: float64

# %%
def knn_comparison(data, k):
    x = data[['horas_asincronas','valoracion_clases']].values
    y = data['ind_nivel_am'].values

    clf = neighbors.KNeighborsClassifier(n_neighbors=k)

    clf.fit(x, y)
    # Plotting decision region
    plot_decision_regions(x, y, clf=clf, legend=2)
    # Adding axes annotations
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Knn with K=8')
    plt.show()
    

knn_comparison(dataframe, 8)

# %% [markdown]
# <p style="color:red;font-size:2rem"> <b>Para el caso de Geometría</b></p>

# %%
X = dataframe[['id','seccion','edad','pf_ac1','pf_ac2','pf_ac3','pf_geo_2019','pf_geo_2020','geo_1b_2021','geo_2b_2021',
               'geo_3b_2021','geo_4b_2021','grupo_mate','genero',
               'anios_colegio','condicion_pago','pe1','pe5','horas_asincronas','valoracion_clases',
               'dispos_clases','calidad_internet']].values
y = dataframe['ind_nivel_geo'].values
 
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
n_neighbors = 1
knn = KNeighborsClassifier(n_neighbors)
knn.fit(X_train, y_train)
print('Accuracy of K-NN classifier on training set: {:.2f}'
     .format(knn.score(X_train, y_train)))
print('Accuracy of K-NN classifier on test set: {:.2f}'
     .format(knn.score(X_test, y_test)))
# Out:
# Accuracy of K-NN classifier on training set: 1.00
# Accuracy of K-NN classifier on test set: 0.89

# %%
df = dataframe[['id','seccion','edad','pf_ac1','pf_ac2','pf_ac3','pf_geo_2019','pf_geo_2020','geo_1b_2021','geo_2b_2021',
               'geo_3b_2021','geo_4b_2021','grupo_mate','genero',
               'anios_colegio','condicion_pago','pe1','pe5','horas_asincronas','valoracion_clases',
               'dispos_clases','calidad_internet']]

df
# Out:
#       id  seccion  edad  pf_ac1  pf_ac2  pf_ac3  pf_geo_2019  pf_geo_2020  \
# 0    488        0    16      15      16      20           15           14
# 1    489        0    17      12      15      20           14           13
# 2    490        0    16      12      13      18           12           11
# 3    491        0    16      18      17      18           17           14
# 4    492        0    16      15      14      19           12           15
# ..   ...      ...   ...     ...     ...     ...          ...          ...
# 219  707        7    17      16      14      18           16           14
# 220  708        7    16      15      16      18           15           13
# 221  709        7    16      16      16      19           14           16
# 222  710        7    17      16      14      15           11           14
# 223  711        7    17      15      17      20           18           17
#
#      geo_1b_2021  geo_2b_2021  ...  grupo_mate  genero  anios_colegio  \
# 0             14           15  ...           0       0              5
# 1             13           15  ...           0       0              5
# 2             15           10  ...           0       1              5
# 3             14           17  ...           0       0              5
# 4             14           15  ...           0       0              5
# ..           ...          ...  ...         ...     ...            ...
# 219           12           17  ...           0       1              5
# 220           14           15  ...           0       1              5
# 221           14           15  ...           0       1              5
# 222           14           13  ...           0       1              5
# 223           17           18  ...           0       0              5
#
#      condicion_pago  pe1  pe5  horas_asincronas  valoracion_clases  \
# 0                 0    0    0                 1                  2
# 1                 0    0    0                 1                  2
# 2                 0    3    0                 1                  2
# 3                 0    0    0                 1                  2
# 4                 0    0    0                 1                  2
# ..              ...  ...  ...               ...                ...
# 219               0    0    0                 1                  2
# 220               0    0    0                 1                  2
# 221               0    0    0                 1                  2
# 222               0    0    0                 1                  2
# 223               0    2    0                 1                  2
#
#      dispos_clases  calidad_internet
# 0                4                 0
# 1                1                 0
# 2                1                 0
# 3                1                 0
# 4                1                 0
# ..             ...               ...
# 219              4                 0
# 220              2                 0
# 221              3                 0
# 222              1                 0
# 223              3                 0
#
# [224 rows x 22 columns]

# %% [markdown]
# #### Precisión del modelo

# %%
pred = knn.predict(X_test)
print(confusion_matrix(y_test, pred))
print(classification_report(y_test, pred))
# Out:
# [[17  6]
#  [ 0 33]]
#               precision    recall  f1-score   support
#
#            2       1.00      0.74      0.85        23
#            3       0.85      1.00      0.92        33
#
#     accuracy                           0.89        56
#    macro avg       0.92      0.87      0.88        56
# weighted avg       0.91      0.89      0.89        56

# %%
correlation_matrix = dataframe[['id','seccion','edad','pf_ac1','pf_ac2','pf_ac3','pf_geo_2019','pf_geo_2020','geo_1b_2021','geo_2b_2021',
               'geo_3b_2021','geo_4b_2021','grupo_mate','genero',
               'anios_colegio','condicion_pago','pe1','pe5','horas_asincronas','valoracion_clases',
               'dispos_clases','calidad_internet','ind_nivel_geo']].corr()
correlation_matrix["ind_nivel_geo"]
# Out:
# id                   0.013188
# seccion              0.000694
# edad                 0.042378
# pf_ac1               0.632241
# pf_ac2               0.670788
# pf_ac3               0.499206
# pf_geo_2019          0.725825
# pf_geo_2020          0.749330
# geo_1b_2021          0.617636
# geo_2b_2021          0.747422
# geo_3b_2021          0.753650
# geo_4b_2021          0.686573
# grupo_mate                NaN
# genero              -0.121025
# anios_colegio             NaN
# condicion_pago            NaN
# pe1                 -0.307422
# pe5                 -0.509052
# horas_asincronas     0.642139
# valoracion_clases    0.509052
# dispos_clases       -0.111841
# calidad_internet    -0.027798
# ind_nivel_geo        1.000000
# Name: ind_nivel_geo, dtype: float64

# %%
def knn_comparison(data, k):
    x = data[['horas_asincronas','valoracion_clases']].values
    y = data['ind_nivel_am'].values

    clf = neighbors.KNeighborsClassifier(n_neighbors=k)

    clf.fit(x, y)
    # Plotting decision region
    plot_decision_regions(x, y, clf=clf, legend=2)
    # Adding axes annotations
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Knn with K=1')
    plt.show()
    

knn_comparison(dataframe, 1)
